# %%
print("Hello World")
# Out:
# Hello World

# %%
len("Where is the Sultanahmet")
# Out:
# 24

# %%
spacecraft = 'KF1500'
print(f'Selam {spacecraft}!')
# Out:
# Selam KF1500!

# %%
arrivederci='Maradona'
print(f'Mi Manchi {arrivederci}!')
# Out:
# Mi Manchi Maradona!

# %%
size1='large'
size2='medium'

print(f'my size: {size1} and your size: {size2}')
# Out:
# my size: large and your size: medium

# %%
isim='Uğur'
yaş=30
print("Onun ismi {} ve o {} yaşında." .format(isim, yaş))
# Out:
# Onun ismi Uğur ve o 30 yaşında.

# %%
a=50
type(a)
# Out:
# int

# %%
x=5
print(x+5)
print(x*5)
print(x-5)
print(x/5)
print(x**5)
print(x**10)
print(x//5)
print(x%5)
# Out:
# 10
# 25
# 0
# 1.0
# 3125
# 9765625
# 1
# 0

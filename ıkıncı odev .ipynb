# %%
print("Welcome to the Orlando Universal Studious")

input ("Please tell me your first name: ")

input ("Please tell me your last name: ")

input ("Date of birth as a year: ")

age = float(input ("Please tell me your age: "))

if age<18:
    print("You can't go out because its dangerous")
else:
    if age>=18:
        print("You can go out to the street")
# Out:
# Welcome to the Orlando Universal Studious
# Please tell me your first name: gg
# Please tell me your last name: ggg
# Date of birth as a year: gggg
# Please tell me your age: 17
# You can't go out because its dangerous

# %%
my_list = list()
name = input("Plaese enter your first name : ")
my_list.append(name)

print (type(name))

lastname = input(" Please enter your last name : ")
my_list.append(lastname)

print (type(lastname))

age = int(input(" Your age : "))
my_list.append(age)

print (type(age))

job = input(" Could you tell us your job : ")
my_list.append(job)

print (type(job))

salary = float(input("Please enter your salary :"))
my_list.append(salary)

print (type(salary))
